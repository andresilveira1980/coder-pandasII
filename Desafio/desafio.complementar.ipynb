# %%
import pandas as pd

# %%
df= pd.read_excel('best-selling game consoles.xlsx')

console = pd.ExcelFile('best-selling game consoles.xlsx')

console.sheet_names
# Out:
# ['info', 'consoles']

# %%
df.head()
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   https://www.kaggle.com/datasets/tayyarhussain/best-selling-game-consoles-of-all-time
# 0                                                NaN
# 1  This dataset contains information about the be...
# 2                                                NaN
# 3        Console Name: The name of the game console.
# 4  Type: The type of console (e.g., home console,...

# %%
df= pd.read_excel('best-selling game consoles.xlsx', sheet_name='consoles')

# %%
df.head
# Out:
# <bound method NDFrame.head of                          Console Name                 Type  \
# 0                       PlayStation 2                 Home
# 1                         Nintendo DS             Handheld
# 2                     Nintendo Switch               Hybrid
# 3                            Game Boy             Handheld
# 4                      Game Boy Color             Handheld
# 5                       PlayStation 4                 Home
# 6                         PlayStation                 Home
# 7                                 Wii                 Home
# 8                       PlayStation 3                 Home
# 9                            Xbox 360                 Home
# 10                   Game Boy Advance             Handheld
# 11               PlayStation Portable             Handheld
# 12                       Nintendo 3DS             Handheld
# 13                        NES/Famicom                 Home
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Console Name          51 non-null     object
#  1   Type                  51 non-null     object
#  2   Company               51 non-null     object
#  3   Released Year         51 non-null     int64
#  4   Discontinuation Year  51 non-null     int64
#  5   Units sold (million)  51 non-null     float64
#  6   Remarks               16 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# Console Name             0
# Type                     0
# Company                  0
# Released Year            0
# Discontinuation Year     0
# Units sold (million)     0
# Remarks                 35
# dtype: int64

# %%
df.head()
# Out:
#       Console Name      Type   Company  Released Year  Discontinuation Year  \
# 0    PlayStation 2      Home      Sony           2000                  2013
# 1      Nintendo DS  Handheld  Nintendo           2004                  2013
# 2  Nintendo Switch    Hybrid  Nintendo           2017                     0
# 3         Game Boy  Handheld  Nintendo           1989                  2003
# 4   Game Boy Color  Handheld  Nintendo           1998                  2003
#
#    Units sold (million)                                            Remarks
# 0                155.00           Final sales are greater than 155 million
# 1                154.02                                                NaN
# 2                122.55                                                NaN
# 3                 64.42  The Game Boy (1989) and the Game Boy Color (19...
# 4                 44.06                                                NaN

# %%
df.describe()
# Out:
#        Released Year  Discontinuation Year  Units sold (million)
# count      51.000000             51.000000             51.000000
# mean     1996.058824           1844.803922             35.549412
# std        12.378064            543.657319             42.608844
# min      1976.000000              0.000000              1.000000
# 25%      1987.500000           1992.000000              3.200000
# 50%      1994.000000           1998.000000             13.560000
# 75%      2004.500000           2011.500000             60.205000
# max      2020.000000           2020.000000            155.000000

# %%
num_consoles = len(df)
num_consoles
# Out:
# 51

# %%
consoles_por_companhia = df.groupby('Company').size()
consoles_por_companhia
# Out:
# Company
# Atari                       4
# Bandai                      1
# Coleco                      2
# Magnavox/Philips            1
# Mattel                      1
# Micro Genius                1
# Microsoft                   4
# NEC                         1
# NEC/Hudson Soft[note 6]     1
# Nintendo                   17
# Nokia                       1
# Philips                     1
# Sega                        7
# Sony                        7
# Tectoy                      2
# dtype: int64

# %%
consoles_por_companhia = df.groupby('Company').size().sort_values(ascending=False)
consoles_por_companhia
# Out:
# Company
# Nintendo                   17
# Sega                        7
# Sony                        7
# Atari                       4
# Microsoft                   4
# Coleco                      2
# Tectoy                      2
# Bandai                      1
# Magnavox/Philips            1
# Mattel                      1
# Micro Genius                1
# NEC                         1
# NEC/Hudson Soft[note 6]     1
# Nokia                       1
# Philips                     1
# dtype: int64

# %%
df.columns
# Out:
# Index(['Console Name', 'Type', 'Company', 'Released Year',
#        'Discontinuation Year', 'Units sold (million)', 'Remarks',
#        'Market Value'],
#       dtype='object')

# %%
market_values = [100, 200, 150, 300, 50, 400, 250, 350, 600, 700, 450, 220, 80, 90, 500,
                 650, 200, 750, 320, 410, 190, 370, 600, 150, 280, 620, 540, 750, 210, 330,
                 180, 900, 110, 170, 600, 440, 300, 500, 650, 500, 850, 200, 650, 300, 700,
                 550, 500, 420, 330, 410, 170]

df['Market Value'] = market_values[:len(df)]

# %%
df['Market Value']
# Out:
# 0     100
# 1     200
# 2     150
# 3     300
# 4      50
# 5     400
# 6     250
# 7     350
# 8     600
# 9     700
# 10    450
# 11    220
# 12     80
# 13     90
# 14    500
# 15    650
# 16    200
# 17    750
# 18    320
# 19    410
# 20    190
# 21    370
# 22    600
# 23    150
# 24    280
# 25    620
# 26    540
# 27    750
# 28    210
# 29    330
# 30    180
# 31    900
# 32    110
# 33    170
# 34    600
# 35    440
# 36    300
# 37    500
# 38    650
# 39    500
# 40    850
# 41    200
# 42    650
# 43    300
# 44    700
# 45    550
# 46    500
# 47    420
# 48    330
# 49    410
# 50    170
# Name: Market Value, dtype: int64

# %%
consoles_por_companhia = df.groupby('Company').agg({
    'Console Name': 'size',        
    'Market Value': 'sum'          
}).sort_values(by='Console Name', ascending=False)

consoles_por_companhia
# Out:
#                          Console Name  Market Value
# Company
# Nintendo                           17          6010
# Sega                                7          3270
# Sony                                7          2600
# Atari                               4          1280
# Microsoft                           4          1720
# Coleco                              2           710
# Tectoy                              2          1750
# Bandai                              1           300
# Magnavox/Philips                    1           700
# Mattel                              1           500
# Micro Genius                        1           110
# NEC                                 1           550
# NEC/Hudson Soft[note 6]             1           210
# Nokia                               1           200
# Philips                             1           330
